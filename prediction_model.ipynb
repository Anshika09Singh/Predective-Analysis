# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshika09Singh/Predective-Analysis/blob/main/prediction_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Giridharan79/HOUSE_PRICE_PREDICTION/refs/heads/main/final_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  beds  baths    size  zip_code      price
# 0           0     3    2.5  2590.0     98144   795000.0
# 1           1     4    2.0  2240.0     98106   915000.0
# 2           2     4    3.0  2040.0     98107   950000.0
# 3           3     4    3.0  3800.0     98199  1950000.0
# 4           4     2    2.0  1042.0     98102   950000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2016 non-null   int64
#  1   beds        2016 non-null   int64
#  2   baths       2016 non-null   float64
#  3   size        2016 non-null   float64
#  4   zip_code    2016 non-null   int64
#  5   price       2016 non-null   float64
# dtypes: float64(3), int64(3)
# memory usage: 94.6 KB

# %%
# visualization - corelation
from pandas.plotting  import scatter_matrix
attributes = []

# %%
df.describe()
# Out:
#         Unnamed: 0         beds        baths          size      zip_code  \
# count  2016.000000  2016.000000  2016.000000   2016.000000   2016.000000
# mean   1007.500000     2.857639     2.159970   1735.740575  98123.638889
# std     582.113391     1.255092     1.002023    920.132591     22.650819
# min       0.000000     1.000000     0.500000    250.000000  98101.000000
# 25%     503.750000     2.000000     1.500000   1068.750000  98108.000000
# 50%    1007.500000     3.000000     2.000000   1560.000000  98117.000000
# 75%    1511.250000     4.000000     2.500000   2222.500000  98126.000000
# max    2015.000000    15.000000     9.000000  11010.000000  98199.000000
#
#               price
# count  2.016000e+03
# mean   9.636252e+05
# std    9.440954e+05
# min    1.590000e+05
# 25%    6.017500e+05
# 50%    8.000000e+05
# 75%    1.105250e+06
# max    2.500000e+07

# %%
df.corr()['price']
# Out:
# Unnamed: 0    0.017196
# beds          0.293516
# baths         0.317325
# size          0.444140
# zip_code     -0.047189
# price         1.000000
# Name: price, dtype: float64

# %%
# size highlly corealted
from pandas.plotting import scatter_matrix
attributes = ["price" , "size"]
scatter_matrix(df[attributes] , figsize=(12,8))
# Out:
# array([[<Axes: xlabel='price', ylabel='price'>,
#         <Axes: xlabel='size', ylabel='price'>],
#        [<Axes: xlabel='price', ylabel='size'>,
#         <Axes: xlabel='size', ylabel='size'>]], dtype=object)

# %%
# # data cleaning
# if object is exist is ocean proximity then drop it if not then no worries
#df = df.drop(['ocean _proxomity'] , axis=1)
# check it

# %%
# # fill null values
# df.isna().sum()
# # median = df['column name'].median()
# df['column name'].fillna(median, inplace=True)
# # check it
# # in this data set there is no  null values dont need to do it

# %%
# according to finding correlation between column we observe that its graph is linearly variable then use linear regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x = df.drop(['zip_code'] , axis=1)
y = df['size']
x.head()
# Out:
#    Unnamed: 0  beds  baths    size      price
# 0           0     3    2.5  2590.0   795000.0
# 1           1     4    2.0  2240.0   915000.0
# 2           2     4    3.0  2040.0   950000.0
# 3           3     4    3.0  3800.0  1950000.0
# 4           4     2    2.0  1042.0   950000.0

# %%
# train and testing
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2)

# %%
# function call
lir = LinearRegression()
lir.fit(x_train , y_train)
lir.score(x_train , y_train)
# Out:
# 1.0

# %%
lir.score(x_test , y_test)
# Out:
# 1.0

# %% [markdown]
# Perfect Accuracy generated
# # New Section
